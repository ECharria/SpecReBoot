# %% [markdown]
# # Phylo2MSClust

# %% [markdown]
# ## First lets preprocess our spectra

# %%
import matchms.filtering as msfilters
from matchms.importing import load_from_mgf


def spectrum_processing(s):
    """This is how one would typically design a desired pre- and post-
    processing pipeline."""
    s = msfilters.default_filters(s)
    s = msfilters.add_parent_mass(s)
    s = msfilters.normalize_intensities(s)
    s = msfilters.reduce_to_number_of_peaks(s, n_required=10, ratio_desired=0.5, n_max=500)
    s = msfilters.select_by_mz(s, mz_from=0, mz_to=1000)
    s = msfilters.require_minimum_number_of_peaks(s, n_required=10)
    return s

# Load data from MGF file and apply filters
spectrums = [spectrum_processing(s) for s in load_from_mgf("/Users/rtlortega/Documents/PhD/Datasets/pesticides.mgf")]
# Out:
# 2025-10-21 17:51:53,216:WARNING:matchms:interpret_unknown_adduct:Charge was found 0 times in adduct [M+K-2H]

# %% [markdown]
# ## Peak binning

# %%
import numpy as np

decimals = 1 # change
# Collect all rounded m/z values across spectra
all_bins = []
for spec in spectrums:
    binned_mz = np.round(spec.peaks.mz, decimals)
    all_bins.extend(binned_mz)

# Create global vocabulary of bins (rounded m/z centers)
global_bins = sorted(set(all_bins))# global vocabulary of bins

# %% [markdown]
# ## Same spectra with the binned peaks

# %%
from matchms import Scores, Spectrum
import numpy as np


list_of_binned_spectra = []

for spec in spectrums:
    mz_rounded = np.round(spec.peaks.mz, decimals)

    spectrum = Spectrum(mz=mz_rounded,
                    intensities=spec.peaks.intensities,
                    metadata=spec.metadata)

    list_of_binned_spectra.append(spectrum)

# %%
from matchms import calculate_scores
#from matchms.similarity import ModifiedCosine
#from matchms.similarity import CosineGreedy
from matchms.similarity import FlashSimilarity

# %%
from collections import defaultdict, Counter
from itertools import combinations
import numpy as np
import pandas as pd

def calculate_boostrapping(list_of_binned_spectra, global_bins, B, k, spectra_similarity_metric): 
    # for later
    pair_sims_sum = defaultdict(float)
    pair_counts   = defaultdict(int)
    edge_support  = Counter()

    scan_ids = [s.get("scans") for s in list_of_binned_spectra]
    scan_to_idx = {sid: idx for idx, sid in enumerate(scan_ids)}

    for b in range(B):
        # sample P bins with replacement
        sampled_bin_indices = rng.integers(0, P, size=P)
        sampled_bins = [global_bins[i] for i in sampled_bin_indices]

        # build the resampled spectra
        spectra_boot = []
        for spec in list_of_binned_spectra:
            kept_mz = [mz for mz in spec.peaks.mz if mz in sampled_bins]
            kept_int = [spec.peaks.intensities[i] for i, mz in enumerate(spec.peaks.mz) if mz in sampled_bins]
            spec_copy = Spectrum(
                mz=np.array(kept_mz),
                intensities=np.array(kept_int),
                metadata=spec.metadata
            )
            spectra_boot.append(spec_copy)
        
        # skip empty set
        if len(spectra_boot) == 0:
            continue

        # compute similarities
        scores = calculate_scores(spectra_boot, spectra_boot, spectra_similarity_metric)

        sim_matrix = np.zeros((N, N), dtype=float)


        for ref_spec, query_spec, score_value in scores:
            i = scan_to_idx[ref_spec.get("scans")]
            j = scan_to_idx[query_spec.get("scans")]
            if i == j:
                continue
            sim_val = score_value[0]
            sim_matrix[i, j] = sim_matrix[j, i] = sim_val

            pair_sims_sum[(scan_ids[i], scan_ids[j])] += sim_val
            pair_counts[(scan_ids[i], scan_ids[j])] += 1


        # compute kNN for edge support
        for i in range(N):
            idx_sorted = np.argsort(sim_matrix[i])[::-1]
            knn_i = idx_sorted[1:k+1]  # skip self
            for j in knn_i:
                idx_sorted_j = np.argsort(sim_matrix[j])[::-1]
                knn_j = idx_sorted_j[1:k+1]
                if i in knn_j:
                    edge_support[tuple(sorted((scan_ids[i], scan_ids[j])))] += 1
        
        # mean similarity matrix
    mean_sim_mat = np.eye(N, dtype="float32")
    for (i, j), total_sim in pair_sims_sum.items():
        count = pair_counts[(i, j)]
        mean_sim_mat[scan_to_idx[i], scan_to_idx[j]] = mean_sim_mat[scan_to_idx[j], scan_to_idx[i]] = total_sim / count

    df_mean_sim = pd.DataFrame(mean_sim_mat, index=scan_ids, columns=scan_ids)

    # edge support matrix (fraction of bootstraps where edge was mutual with the kNN)
    edge_sup_mat = np.zeros((N, N), dtype="float32")
    for (i, j), cnt in edge_support.items():
        edge_sup_mat[scan_to_idx[i], scan_to_idx[j]] = edge_sup_mat[scan_to_idx[j], scan_to_idx[i]] = cnt / B

    df_edge_sup = pd.DataFrame(edge_sup_mat, index=scan_ids, columns=scan_ids)

    return df_mean_sim, df_edge_sup

# %%
# Customise!
N = len(list_of_binned_spectra)
P = len(global_bins)
rng = np.random.default_rng(42)
B = 100
k=5

# %%
df_mean_sim, df_edge_sup = calculate_boostrapping(list_of_binned_spectra, global_bins, B, k, spectra_similarity_metric=FlashSimilarity(tolerance=0.02))
# Out:
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 449600.99it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 7136.04it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 7734.63it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 12305.71it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 5303.50it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 6182.33it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 10751.36it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 9260.56it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 21017.15it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 25434.22it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 5545.90it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 71089.90it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 9363.11it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 10048.77it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 12185.29it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 5845.72it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 11821.07it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 12754.26it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 12649.99it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 16725.28it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 23684.31it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 31187.47it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 8349.06it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 8565.32it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 7441.57it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 10265.92it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 12246.61it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 9790.14it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 11298.99it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 10705.86it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 15905.75it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 5418.81it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 26126.31it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 11777.83it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 23271.07it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 6769.32it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 8831.09it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 8980.62it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 8215.44it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 9576.61it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 13265.93it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 37885.32it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 9221.18it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 11169.92it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 2920.37it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 9336.78it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 36297.78it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 9312.51it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 6370.50it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 6330.14it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 7583.19it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 9776.03it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 15609.77it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 6666.68it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 26453.70it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 9152.35it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 6425.46it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 19471.45it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 9895.91it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 7333.21it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 12621.94it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 24564.01it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 14629.73it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 11326.29it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 6131.43it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 8040.54it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 6793.70it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 7025.94it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 8666.86it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 14676.88it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 9839.40it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 9303.54it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 6906.45it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 63423.62it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 7372.38it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 28347.45it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 20021.80it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 7904.17it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 21428.28it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 19163.59it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 96830.83it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 8291.29it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 31533.00it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 15097.43it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 18455.71it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 10098.43it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 8868.19it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 15291.52it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 18030.83it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 10308.08it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 12183.42it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 12323.31it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 15022.72it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 14429.07it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 17462.86it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 17273.60it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 8407.19it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 9308.97it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 6954.06it/s]
# Flash spectral_entropy (fragment) (parallel x10): 100%|██████████| 76/76 [00:00<00:00, 25700.81it/s]

# %% [markdown]
# ## Lets visualise it

# %%
import matplotlib.pyplot as plt

# use the same scan IDs that index your DataFrames
names = df_mean_sim.index.tolist()

plt.figure(figsize=(7,6))
plt.imshow(df_mean_sim.values, interpolation="nearest", cmap="viridis")
plt.xticks(range(len(names)), names, rotation=90)
plt.yticks(range(len(names)), names)
plt.colorbar(label="Mean cosine (bootstrap)")
plt.title("Bootstrap mean similarity")
plt.tight_layout()
plt.show()

plt.figure(figsize=(7,6))
plt.imshow(df_edge_sup.values, interpolation="nearest", cmap="viridis", vmin=0, vmax=1)
plt.xticks(range(len(names)), names, rotation=90)
plt.yticks(range(len(names)), names)
plt.colorbar(label="Edge support (mutual kNN)")
plt.title("Consensus edge support")
plt.tight_layout()
plt.show()
